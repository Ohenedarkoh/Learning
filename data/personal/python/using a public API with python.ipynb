# %%
#using a public API  with python

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '0acd490e-493c-4b80-b220-116dd0ef266b',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-11-19T14:17:56.454Z', 'error_code': 0, 'error_message': None, 'elapsed': 1, 'credit_count': 1, 'notice': None}, 'data': [{'id': 6126, 'name': 'vihoo7iig6', 'symbol': 'av5yteko1uf', 'slug': 'hngx8x7w6ec', 'cmc_rank': 131, 'num_market_pairs': 6551, 'circulating_supply': 7418, 'total_supply': 9307, 'max_supply': 850, 'infinite_supply': None, 'last_updated': '2024-11-19T14:17:56.454Z', 'date_added': '2024-11-19T14:17:56.454Z', 'tags': ['x7gu9mxifjf', 'ab6uimgoya', 'jb5wz4tgrgo', 'b2ksbn5cnyt', 'o6um145jemk', 'h1i9paw9h3m', 'ftv2pq994x9', 'woa56iii6u', '8noiq04hymj', '2xwby0wupqa'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.5615468801617653, 'volume_24h': 9102, 'volume_change_24h': 0.6498595180956204, 'percent_change_1h': 0.4344750793604435, 'percent_change_24h': 0.7495905712744211, 'percent_change_7d': 0.08470496789181947, 'market_cap': 0.5833847816446835, 'market_cap_dominance': 9527, 'fully_diluted_market_cap': 0.0769892283818554, 'last_updated': '2024-11-19T14:17:56.454Z'}}}, {'id': 9859, 'name': 'jfl2hokmv8', 'symbol': 'xqd3e1b02tj', 'slug': 'qlsmlt8wllh', 'cmc_rank': 7531, 'num_market_pairs': 140, 'circulating_supply': 134, 'total_supply': 3769, 'max_supply': 5269, 'infinite_supply': None, 'last_updated': '2024-11-19T14:17:56.454Z', 'date_added': '2024-11-19T14:17:56.454Z', 'tags': ['zd7vbmtec4i', 'qv1upvcmo5h', '94cs63r01q', 'wd7ctyz5xcc', 'uaujm2ax6h', '58uplyk60fk', '2ta92lagbih', 'g1twvue3cj', 'nuuykyj2ros', 'nuplowe4458'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.5005163550819154, 'volume_24h': 5877, 'volume_change_24h': 0.02908004127875552, 'percent_change_1h': 0.8108624660310637, 'percent_change_24h': 0.5837073761665037, 'percent_change_7d': 0.021282955792400138, 'market_cap': 0.7615094571030216, 'market_cap_dominance': 3727, 'fully_diluted_market_cap': 0.6118361955597982, 'last_updated': '2024-11-19T14:17:56.454Z'}}}, {'id': 7856, 'name': 'lsafwjla6i', 'symbol': 's8dwsvkb9bk', 'slug': '2qd8frakz2', 'cmc_rank': 450, 'num_market_pairs': 6301, 'circulating_supply': 2064, 'total_supply': 2738, 'max_supply': 4416, 'infinite_supply': None, 'last_updated': '2024-11-19T14:17:56.454Z', 'date_added': '2024-11-19T14:17:56.454Z', 'tags': ['xsqk3g3uprp', 'rt3kset5cdf', 'ejlam2j0xr', '4vq4ypfq0go', 'wqmzs97dtr', 'qbbkexs2kne', 'n0pp54deyn', 'tf5fcjb8zoe', 'kbrlf4zrkkq', 'xwrdcvyfz6'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.9500679460456596, 'volume_24h': 7984, 'volume_change_24h': 0.43780771609435276, 'percent_change_1h': 0.8832351408995123, 'percent_change_24h': 0.507952936006214, 'percent_change_7d': 0.5435701511848903, 'market_cap': 0.4170092809641197, 'market_cap_dominance': 5110, 'fully_diluted_market_cap': 0.5468178260746932, 'last_updated': '2024-11-19T14:17:56.454Z'}}}, {'id': 848, 'name': 'cc95cnuik8e', 'symbol': 'b2ozsjbko0q', 'slug': '5s68xib7b0n', 'cmc_rank': 1877, 'num_market_pairs': 844, 'circulating_supply': 5405, 'total_supply': 2186, 'max_supply': 8384, 'infinite_supply': None, 'last_updated': '2024-11-19T14:17:56.454Z', 'date_added': '2024-11-19T14:17:56.454Z', 'tags': ['uky14kh0bw', 'butm64rzoxp', 'n5kkhjoabzf', 'ajrudmixup', 'z0myy3xywd', 'e5e5yni9q7m', 'jlq0sjt1lxb', 'ehhq6qqx9l', 's58zxa76khe', '12yeh2lwrw0k'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.9002312616828654, 'volume_24h': 3263, 'volume_change_24h': 0.27863156173468595, 'percent_change_1h': 0.4224979248708254, 'percent_change_24h': 0.4817176238529588, 'percent_change_7d': 0.09110486515356753, 'market_cap': 0.12732938519161663, 'market_cap_dominance': 4162, 'fully_diluted_market_cap': 0.920787290517413, 'last_updated': '2024-11-19T14:17:56.454Z'}}}, {'id': 8533, 'name': 'qg80c86sar', 'symbol': 'f2r ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd

pd.set_option('display.max_columns', None

# %%
pd.json_normalize(data['data'])
# Out:
#      id         name       symbol         slug  cmc_rank  num_market_pairs  \
# 0  6126   vihoo7iig6  av5yteko1uf  hngx8x7w6ec       131              6551
# 1  9859   jfl2hokmv8  xqd3e1b02tj  qlsmlt8wllh      7531               140
# 2  7856   lsafwjla6i  s8dwsvkb9bk   2qd8frakz2       450              6301
# 3   848  cc95cnuik8e  b2ozsjbko0q  5s68xib7b0n      1877               844
# 4  8533   qg80c86sar  f2rtlhkjo9u  9gaz5d5if79      1150              1846
# 5  7856  rmdaofm8bqn   ximycqm8kq   y7rr31ag66      9414              1013
# 6  9150  voz3ngfk7rg  xkl4szr7c5r  8ipxzd66c3u      7291              1559
# 7  3909  8jg8znrgsz6  oevvvtd2fwa  ut1q6nmczpo       881              5128
# 8  6307  8zvuuc26g9o  v8wfy7xfiy9  9poauwxbq5p      6539              7928
# 9  3062  1fshuydb2zv  vhih7kg9i7r   hn5sd45dro      8416              1543
#
#    circulating_supply  total_supply  max_supply infinite_supply  ...  \
# 0                7418          9307         850            None  ...
# 1                 134          3769        5269            None  ...
# 2                2064          2738        4416            None  ...
# 3                5405          2186        8384            None  ...
# 4                4147          9950        2122            None  ...
# 5                6289          6822        7705            None  ...
# 6                 964           827        4136            None  ...
# 7                5852          6148        9851            None  ...
# 8                7247          9749         207            None  ...
# 9                7489          7491        7748            None  ...
#
#   quote.USD.price quote.USD.volume_24h quote.USD.volume_change_24h  \
# 0        0.561547                 9102                    0.649860
# 1        0.500516                 5877                    0.029080
# 2        0.950068                 7984                    0.437808
# 3        0.900231                 3263                    0.278632
# 4        0.234951                 7508                    0.914269
# 5        0.347925                 4528                    0.031220
# 6        0.382074                   44                    0.200304
# 7        0.400722                  736                    0.056138
# 8        0.091586                 4926                    0.737504
# 9        0.845178                 4983                    0.031691
#
#   quote.USD.percent_change_1h quote.USD.percent_change_24h  \
# 0                    0.434475                     0.749591
# 1                    0.810862                     0.583707
# 2                    0.883235                     0.507953
# 3                    0.422498                     0.481718
# 4                    0.315198                     0.472466
# 5                    0.333864                     0.903485
# 6                    0.826087                     0.326435
# 7                    0.099644                     0.553487
# 8                    0.079357                     0.050483
# 9                    0.220360                     0.009949
#
#   quote.USD.percent_change_7d  quote.USD.market_cap  \
# 0                    0.084705              0.583385
# 1                    0.021283              0.761509
# 2                    0.543570              0.417009
# 3                    0.091105              0.127329
# 4                    0.235148              0.255654
# 5                    0.508263              0.729086
# 6                    0.400620              0.888631
# 7                    0.010812              0.631492
# 8                    0.464230              0.646242
# 9                    0.331069              0.875770
#
#    quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                            9527                            0.076989
# 1                            3727                            0.611836
# 2                            5110                            0.546818
# 3                            4162                            0.920787
# 4                            4748                            0.826424
# 5                            5657                            0.389018
# 6                            9717                            0.468608
# 7                            1505                            0.769992
# 8                            6069                            0.034310
# 9                            9728                            0.174185
#
#      quote.USD.last_updated
# 0  2024-11-19T14:17:56.454Z
# 1  2024-11-19T14:17:56.454Z
# 2  2024-11-19T14:17:56.454Z
# 3  2024-11-19T14:17:56.454Z
# 4  2024-11-19T14:17:56.454Z
# 5  2024-11-19T14:17:56.454Z
# 6  2024-11-19T14:17:56.454Z
# 7  2024-11-19T14:17:56.454Z
# 8  2024-11-19T14:17:56.454Z
# 9  2024-11-19T14:17:56.454Z
#
# [10 rows x 26 columns]
